# %%
import pandas as pd
import numpy as np 
from sklearn.model_selection import train_test_split
import matplotlib as plt 
from sklearn.linear_model import LogisticRegression 
from sklearn.svm import SVC

from sklearn.metrics import accuracy_score
# Out:
# C:\Users\Maan Patel\AppData\Local\Temp\ipykernel_15068\2843567992.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from sklearn.model_selection import train_test_split
#       4 import matplotlib as plt
#       5 from sklearn.linear_model import LogisticRegression
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
train = pd.read_csv("F:\Mini-Project\Mini-Project\Traffic.csv")
train
# Out:
#              Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 0     12:00:00 AM    10         Tuesday        31          0         4
# 1     12:15:00 AM    10         Tuesday        49          0         3
# 2     12:30:00 AM    10         Tuesday        46          0         3
# 3     12:45:00 AM    10         Tuesday        51          0         2
# 4      1:00:00 AM    10         Tuesday        57          6        15
# ...           ...   ...             ...       ...        ...       ...
# 2971  10:45:00 PM     9        Thursday        16          3         1
# 2972  11:00:00 PM     9        Thursday        11          0         1
# 2973  11:15:00 PM     9        Thursday        15          4         1
# 2974  11:30:00 PM     9        Thursday        16          5         0
# 2975  11:45:00 PM     9        Thursday        14          3         1
#
#       TruckCount  Total Traffic Situation
# 0              4     39               low
# ...

# %%
train, test = train_test_split(train, test_size=0.2, random_state=42)
print("Shape of train: ", train.shape)
print("Shape of test", test.shape)
# Out:
# Shape of train:  (2380, 9)
# Shape of test (596, 9)

# %%
test
# Out:
#              Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 2404   1:00:00 AM     4        Saturday        15          5         0
# 2866   8:30:00 PM     8       Wednesday        86         15        15
# 2775   9:45:00 PM     7         Tuesday       102          5        19
# 507    6:45:00 AM    15          Sunday       109         14        38
# 1825  12:15:00 AM    29          Sunday        14          2         1
# ...           ...   ...             ...       ...        ...       ...
# 2040   6:00:00 AM    31         Tuesday       129         31        36
# 2617   6:15:00 AM     6          Monday       123         27        22
# 678    1:30:00 AM    17         Tuesday        20          3         1
# 605    7:15:00 AM    16          Monday       147         26        40
# 1343  11:45:00 PM    23          Monday        11          3         1
#
#       TruckCount  Total Traffic Situation
# 2404          10     30               low
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2380 entries, 1557 to 860
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Time               2380 non-null   object
#  1   Date               2380 non-null   int64
#  2   Day of the week    2380 non-null   object
#  3   CarCount           2380 non-null   int64
#  4   BikeCount          2380 non-null   int64
#  5   BusCount           2380 non-null   int64
#  6   TruckCount         2380 non-null   int64
#  7   Total              2380 non-null   int64
#  8   Traffic Situation  2380 non-null   object
# dtypes: int64(6), object(3)
# memory usage: 185.9+ KB

# %%
from sklearn.preprocessing import LabelEncoder 
le = LabelEncoder()



train_temp = train
train_temp['Day of the week'] = train_temp['Day of the week'].replace({'Monday':1,'Tuesday':2,'Wednesday':3,'Thursday':4,'Friday':5,'Saturday':6,'Sunday':7})
train_temp['Traffic Situation'] = train_temp['Traffic Situation'].replace({'low':1,'normal':2,'high':3, 'heavy':4})
train_temp['Time'] = le.fit_transform(train_temp['Time'])
                                                

train = train_temp

train
# Out:
# C:\Users\Maan Patel\AppData\Local\Temp\ipykernel_19124\2059627957.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   train_temp['Day of the week'] = train_temp['Day of the week'].replace({'Monday':1,'Tuesday':2,'Wednesday':3,'Thursday':4,'Friday':5,'Saturday':6,'Sunday':7})
# C:\Users\Maan Patel\AppData\Local\Temp\ipykernel_19124\2059627957.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   train_temp['Traffic Situation'] = train_temp['Traffic Situation'].replace({'low':1,'normal':2,'high':3, 'heavy':4})
# ...

# %%
test_temp = test
test_temp['Day of the week'] = test_temp['Day of the week'].replace(
    {'Monday': 1, 'Tuesday': 2, 'Wednesday': 3, 'Thursday': 4, 'Friday': 5, 'Saturday': 6, 'Sunday': 7})
test_temp['Traffic Situation'] = test_temp['Traffic Situation'].replace(
    {'low': 1, 'normal': 2, 'high': 3, 'heavy': 4})

test_temp['Time'] = le.fit_transform(test_temp['Time']) 

test = test_temp

test
# Out:
# C:\Users\Maan Patel\AppData\Local\Temp\ipykernel_19124\632298576.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test_temp['Day of the week'] = test_temp['Day of the week'].replace(
# C:\Users\Maan Patel\AppData\Local\Temp\ipykernel_19124\632298576.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test_temp['Traffic Situation'] = test_temp['Traffic Situation'].replace(
#       Time  Date  Day of the week  CarCount  BikeCount  BusCount  TruckCount  \
# ...

# %%
X_test = test.drop(columns=['Traffic Situation'],axis=1)
y_test = test['Traffic Situation']

X_test
# Out:
#       Time  Date  Day of the week  CarCount  BikeCount  BusCount  TruckCount  \
# 2404    24     4                6        15          5         0          10
# 2866    85     8                3        86         15        15          23
# 2775    95     7                2       102          5        19          11
# 507     70    15                7       109         14        38           1
# 1825    18    29                7        14          2         1          26
# ...    ...   ...              ...       ...        ...       ...         ...
# 2040    64    31                2       129         31        36           1
# 2617    66     6                1       123         27        22           4
# 678     28    17                2        20          3         1          32
# 605     74    16                1       147         26        40           0
# 1343    15    23                1        11          3         1          37
#
#       Total
# 2404     30
# 2866    139
# ...

# %%
X_train = train.drop(columns=['Traffic Situation'], axis=1)
y_train = train['Traffic Situation']

model = LogisticRegression()
lr = model.fit(X_train,y_train)

model2 = SVC()
svc = model2.fit(X_train,y_train)
# Out:
# f:\Mini-Project\miniprojectenv\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Prediction for Logictic Regression 
y_predict = model.predict(X_test)

accuracy_lr = accuracy_score(y_test,y_predict)
print("Accuracy of the LR model : ", accuracy_lr*100)


# Prediction for Suppoprt Vector Machine 
y_predict_svc = model2.predict(X_test)

accuracy_score_svc = accuracy_score(y_test,y_predict_svc)
print ("Accuracy of the SVM Model : ", accuracy_score_svc*100)
# Out:
# Accuracy of the LR model :  76.51006711409396
# Accuracy of the SVM Model :  89.42953020134227

# %%
import pickle

# %%
pickle.dump(model,open('TrafficDensityModel.pkl','wb'))

# %%
pickle_model = pickle.load(open('TrafficDensityModel.pkl','rb'))

pickle_predict = pickle_model.predict([[85, 8, 3, 86, 15, 15, 23, 139]])
#pickle.load([58,25,7,150,24,2,0,176])

pickle_predict
# Out:
# f:\Mini-Project\Mini-Project\miniprojectenv\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([2], dtype=int64)

# %%
pickle.dump(model2,open('TrafficDensityModelSVM.pkl','wb'))
pickle_model_svm = pickle.load(open('TrafficDensityModelSVM.pkl','rb'))

pickle_model_svm_predict = pickle_model_svm.predict([[85, 8, 3, 86, 15, 15, 23, 139]])
pickle_model_svm_predict
# Out:
# f:\Mini-Project\miniprojectenv\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# array([3], dtype=int64)
